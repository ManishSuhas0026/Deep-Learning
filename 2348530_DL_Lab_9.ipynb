# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishSuhas0026/Deep-Learning/blob/main/2348530_DL_Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Dropout, BatchNormalization
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
df_train = pd.read_csv('/content/LSTM-Multivariate_pollution.csv')
df_train.head(5)
# Out:
#                   date  pollution  dew  temp   press wnd_dir  wnd_spd  snow  \
# 0  2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79     0
# 1  2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68     0
# 2  2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57     0
# 3  2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36     1
# 4  2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25     2
#
#    rain
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43800 entries, 0 to 43799
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       43800 non-null  object
#  1   pollution  43800 non-null  float64
#  2   dew        43800 non-null  int64
#  3   temp       43800 non-null  float64
#  4   press      43800 non-null  float64
#  5   wnd_dir    43800 non-null  object
#  6   wnd_spd    43800 non-null  float64
#  7   snow       43800 non-null  int64
#  8   rain       43800 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
df_test= pd.read_csv('/content/pollution_test_data1.csv')
df_test.head(5)
# Out:
#    dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0  -16     4   1027      SE     3.58     0     0        128
# 1  -17     5   1027      SE     7.60     0     0         77
# 2  -16     4   1027      SE     9.39     0     0         65
# 3  -16     1   1028      cv     0.89     0     0         79
# 4  -14     0   1028      NE     1.79     0     0         93

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dew        346 non-null    int64
#  1   temp       346 non-null    int64
#  2   press      346 non-null    int64
#  3   wnd_dir    346 non-null    object
#  4   wnd_spd    346 non-null    float64
#  5   snow       346 non-null    int64
#  6   rain       346 non-null    int64
#  7   pollution  346 non-null    int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 21.8+ KB

# %%
df_test.isnull().sum()
# Out:
# dew          0
# temp         0
# press        0
# wnd_dir      0
# wnd_spd      0
# snow         0
# rain         0
# pollution    0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# date         0
# pollution    0
# dew          0
# temp         0
# press        0
# wnd_dir      0
# wnd_spd      0
# snow         0
# rain         0
# dtype: int64

# %%
df_train_scaled = df_train.copy()
df_test_scaled = df_test.copy()

mapping = {'NE': 0, 'SE': 1, 'NW': 2, 'cv': 3}

df_train_scaled['wnd_dir'] = df_train_scaled['wnd_dir'].map(mapping)
df_test_scaled['wnd_dir'] = df_test_scaled['wnd_dir'].map(mapping)

df_train_scaled['date'] = pd.to_datetime(df_train_scaled['date'])

df_train_scaled.set_index('date', inplace=True)
df_train_scaled.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd  snow  \
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36     1
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25     2
#
#                      rain
# date
# 2010-01-02 00:00:00     0
# 2010-01-02 01:00:00     0
# 2010-01-02 02:00:00     0
# 2010-01-02 03:00:00     0
# 2010-01-02 04:00:00     0

# %%
values = df_train_scaled.values
groups = [1, 2, 3, 5, 6]
i = 1

plt.figure(figsize=(20,14))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group], color=cm.plasma(group/len(groups)))
    plt.xlabel('Index')
    plt.title(df_train.columns[group], y=0.75, loc='right', fontsize = 15)
    i += 1
plt.show()

# %%
sns.set(style="darkgrid")

fig, axs = plt.subplots(3,2, figsize=(24,14))

sns.histplot(data=df_test_scaled, x="pollution", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=df_test_scaled, x="dew", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df_test_scaled, x="temp", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df_test_scaled, x="press", kde=True, color="teal", ax=axs[1, 1])
sns.histplot(data=df_test_scaled, x="wnd_dir", kde=True, color="steelblue", ax=axs[2, 0])
sns.histplot(data=df_test_scaled, x="wnd_spd", kde=True, color="goldenrod", ax=axs[2, 1])

plt.show()

# %%
scaler = MinMaxScaler()
columns = (['pollution', 'dew', 'temp', 'press', "wnd_dir", 'wnd_spd',
       'snow', 'rain'])

df_test_scaled = df_test_scaled[columns]

df_train_scaled[columns] = scaler.fit_transform(df_train_scaled[columns])
df_test_scaled[columns] = scaler.transform(df_test_scaled[columns])

df_train_scaled.head()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.129779  0.352941  0.245902  0.527273  0.333333
# 2010-01-02 01:00:00   0.148893  0.367647  0.245902  0.527273  0.333333
# 2010-01-02 02:00:00   0.159960  0.426471  0.229508  0.545455  0.333333
# 2010-01-02 03:00:00   0.182093  0.485294  0.229508  0.563636  0.333333
# 2010-01-02 04:00:00   0.138833  0.485294  0.229508  0.563636  0.333333
#
#                       wnd_spd      snow  rain
# date
# 2010-01-02 00:00:00  0.002290  0.000000   0.0
# 2010-01-02 01:00:00  0.003811  0.000000   0.0
# 2010-01-02 02:00:00  0.005332  0.000000   0.0
# 2010-01-02 03:00:00  0.008391  0.037037   0.0
# 2010-01-02 04:00:00  0.009912  0.074074   0.0

# %%
df_test_scaled.head()
# Out:
#    pollution       dew      temp     press   wnd_dir   wnd_spd  snow  rain
# 0   0.128773  0.352941  0.377049  0.654545  0.333333  0.005349   0.0   0.0
# 1   0.077465  0.338235  0.393443  0.654545  0.333333  0.012219   0.0   0.0
# 2   0.065392  0.352941  0.377049  0.654545  0.333333  0.015278   0.0   0.0
# 3   0.079477  0.352941  0.327869  0.672727  1.000000  0.000752   0.0   0.0
# 4   0.093561  0.382353  0.311475  0.672727  0.000000  0.002290   0.0   0.0

# %%
df_train_scaled = np.array(df_train_scaled)
df_test_scaled = np.array(df_test_scaled)

X = []
y = []
n_future = 1
n_past = 11

#  Train Sets
for i in range(n_past, len(df_train_scaled) - n_future+1):
    X.append(df_train_scaled[i - n_past:i, 1:df_train_scaled.shape[1]])
    y.append(df_train_scaled[i + n_future - 1:i + n_future, 0])
X_train, y_train = np.array(X), np.array(y)

#  Test Sets

X = []
y = []
for i in range(n_past, len(df_test_scaled) - n_future+1):
    X.append(df_test_scaled[i - n_past:i, 1:df_test_scaled.shape[1]])
    y.append(df_test_scaled[i + n_future - 1:i + n_future, 0])
X_test, y_test = np.array(X), np.array(y)

print('X_train shape : {}   y_train shape : {} \n'
      'X_test shape : {}      y_test shape : {} '.format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape : (43789, 11, 7)   y_train shape : (43789, 1)
# X_test shape : (335, 11, 7)      y_test shape : (335, 1)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(16, return_sequences=False))
model.add(Dense(y_train.shape[1]))


model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 11, 32)            5120
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 8273 (32.32 KB)
# Trainable params: 8273 (32.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, callbacks=[early_stopping, checkpoint], shuffle=False)
# Out:
# Epoch 1/100
# 1232/1232 [==============================] - 16s 13ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 2/100
#   12/1232 [..............................] - ETA: 12s - loss: 0.0102 - root_mean_squared_error: 0.1011
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 3/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 4/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021
# Epoch 5/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 6/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0060 - root_mean_squared_error: 0.0776 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 7/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0059 - root_mean_squared_error: 0.0769 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 8/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 9/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 10/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 11/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 12/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 13/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 14/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0869
# Epoch 15/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 16/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 17/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 18/100
# 1232/1232 [==============================] - 15s 12ms/step - loss: 0.0056 - root_mean_squared_error: 0.0745 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 19/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772
# Epoch 20/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 21/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0750
# Epoch 22/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0055 - root_mean_squared_error: 0.0739 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0738
# Epoch 23/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0054 - root_mean_squared_error: 0.0738 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 24/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 25/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 26/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 27/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713
# Epoch 28/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 29/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 30/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0731 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 31/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 32/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 33/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 34/100
# 1232/1232 [==============================] - 14s 12ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 35/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 36/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 37/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 38/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 39/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 40/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 41/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 42/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 43/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 44/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 45/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 46/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0689
# Epoch 47/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 48/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 49/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 50/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0682
# Epoch 51/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 52/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 53/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0718 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 54/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 55/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 56/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 57/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 58/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 59/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 60/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 61/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 62/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 63/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 64/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 65/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 66/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 67/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676
# Epoch 68/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 69/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 70/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 71/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 72/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 73/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 74/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 75/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 76/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 77/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0667
# Epoch 78/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0668
# Epoch 79/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0667
# Epoch 80/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 81/100
# 1232/1232 [==============================] - 14s 11ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 82/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0049 - root_mean_squared_error: 0.0700 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 83/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 84/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 85/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0049 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 86/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 87/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 88/100
# 1232/1232 [==============================] - 22s 18ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 89/100
# 1232/1232 [==============================] - 15s 12ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 90/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 91/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 92/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 93/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 94/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 95/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 96/100
# 1232/1232 [==============================] - 17s 14ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 97/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 98/100
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 99/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 100/100
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657

# %%
best_model = load_model('best_model.h5')

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_predictions = best_model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
test_results.head()
# Out:
# 11/11 [==============================] - 2s 3ms/step
#    Train Predictions    Actual
# 0           0.116101  0.171026
# 1           0.087417  0.160966
# 2           0.109336  0.146881
# 3           0.117941  0.125755
# 4           0.093616  0.130785

# %%
plt.plot(test_results['Train Predictions'][:200], label='Predicted Values')
plt.plot(test_results['Actual'][:200], label='True Values')
plt.legend()
plt.show()
